# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from proj1_helpers import *
DATA_TRAIN_PATH = '../data/train.csv' # TODO: download train data and supply path here 
y, tX, ids = load_csv_data(DATA_TRAIN_PATH)

# %%
with open(DATA_TRAIN_PATH) as f:
    labels = f.readline().split(',')[2:] #remove 2 first, being ID and prediction

# %%
tX.shape
# Out:
# (250000, 30)

# %%
def plot_features_distrib(tX):
    plt.figure(figsize=(15,30))
    for i in range(tX.shape[1]):
        plt.subplot(10,3,i+1)
        plt.hist(tX[:,i], bins=50);
        plt.title("Feature {}: {}".format(i, labels[i]))
    plt.tight_layout()
    plt.show();
plot_features_distrib(tX)

# %%
num_jets = np.array(np.unique(tX[:,22]), dtype=np.int8)
tX_pet_jet_num = [tX[tX[:,22] == x] for x in num_jets]
for i in num_jets:
    plot_features_distrib(tX_pet_jet_num[i])

# %%
plt.hist(tX[y == 1][:,15]);

# %%
plt.hist(tX[y == -1][:,15]);
# Out:
# (array([16670., 16267., 16352., 16771., 16437., 16073., 16499., 16137.,
#         16398., 16729.]),
#  array([-3.142 , -2.5136, -1.8852, -1.2568, -0.6284,  0.    ,  0.6284,
#          1.2568,  1.8852,  2.5136,  3.142 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(tX[tX[:,22] == 0][:,8], bins=200);
plt.yscale('log')

# %% [markdown]
# ### Count of non-trivial variables for each jet

# %%
for i in num_jets:
    print("Jet {}: {}".format(i, 27-sum(np.var(tX[tX[:,22] == i], axis=0) == 0)))
# Out:
# Jet 0: 15
# Jet 1: 19
# Jet 2: 26
# Jet 3: 26
